# %% [markdown]
# <img src='../../images/besm.png' width='150px'>

# %% [markdown]
# <center> درس پردازش زبان‌های طبیعی </center>
# <center> آزمایشگاه پردازش هوشمند متن و زبان و علوم انسانی محاسباتی </center>
# <center> آخرین بروز رسانی بهمن ۱۴۰۱ </center>
#
# <br>
# <center> http://language.ml </center>
# <center> contact: info [AT] language [dot] ml </center>

# %% [markdown]
# </h1> <h1 style='direction:rtl'>انگلیسی - پیش پردازش و بررسی متن

# %% [markdown]
# <h2 style='direction:rtl;'> § نمونه‌ای از متن  </h2>

# %%
import random 
import tqdm
import nltk, re
from nltk.corpus import brown
from nltk import word_tokenize
import string

all_categories = brown.categories()

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
all_categories
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
all_brown_sentences_religion = list(brown.sents(categories=['religion']))
all_brown_sentences_news = list(brown.sents(categories=['news']))

all_brown_tagged_sentences = list(brown.tagged_sents(categories=all_categories))

# %%
all_brown_tagged_sentences[1]
# Out:
# [('The', 'AT'),
#  ('jury', 'NN'),
#  ('further', 'RBR'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('term-end', 'NN'),
#  ('presentments', 'NNS'),
#  ('that', 'CS'),
#  ('the', 'AT'),
#  ('City', 'NN-TL'),
#  ('Executive', 'JJ-TL'),
#  ('Committee', 'NN-TL'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('had', 'HVD'),
#  ('over-all', 'JJ'),
#  ('charge', 'NN'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('election', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('deserves', 'VBZ'),
#  ('the', 'AT'),
#  ('praise', 'NN'),
#  ('and', 'CC'),
#  ('thanks', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('City', 'NN-TL'),
#  ('of', 'IN-TL'),
#  ('Atlanta', 'NP-TL'),
#  ("''", "''"),
#  ('for', 'IN'),
#  ('the', 'AT'),
#  ('manner', 'NN'),
#  ('in', 'IN'),
#  ('which', 'WDT'),
#  ('the', 'AT'),
#  ('election', 'NN'),
#  ('was', 'BEDZ'),
#  ('conducted', 'VBN'),
#  ('.', '.')]

# %%
for x in random.sample(all_brown_sentences_religion, 30):
    print(' '.join(x))
# Out:
# you cannot go to heaven unless you are born again .
# for still others , mostly of the nineteenth-century immigration , it was Roman Catholicism , and for a small minority it was Eastern Orthodoxy .
# Our Lord's invitation with its implied promise to all is , `` Come and see '' .
# All have gone astray together ; ;
# Read the next two verses : `` When the wicked , even mine enemies and my foes , came upon me to eat up my flesh , they stumbled and fell .
# I place His precepts and His leadings above every seeming probability , dismissing cherished convictions and holding the wisdom of man as folly when opposed to Him .
# Can the church risk assuming that the `` folly '' of men is as dear to God as their `` wisdom '' , or , as is also commonly implied , that `` the foolishness of God '' and `` the foolishness of men '' are simply two ways of talking about the same thing ? ?
# that is a figure one with 27 ciphers , quite a large number .
# Indeed , mathematically speaking , it was both functionally and symbolically the most important number in the entire diagram .
# What is there about us that makes us so anxious ? ?
# Expressed differently : if the price for becoming a faithful follower of Jesus Christ is some form of self-destruction , whether of the body or of the mind -- sacrificium corporis , sacrificium intellectus -- then there is no alternative but that the price remain unpaid .
# Further evidence that Roman Catholicism enjoys a more favorable position today than in 1861 is the respectful attention given to it in the mass media of England .
# America , America , God mend thy every flaw , confirm thy soul in self control , the liberty in law .
# The rationale for this avoidance was most frequently expressed in economic terms ; ;
# For if I knew the secret of letting this power in my body change directly into electricity , I could rent myself out to the electric companies and with just the power in my body I could light all the lights and run all the factories in the entire United States for some days .
# ) Tillich as well .
# And the life that I now live in the flesh , I live in the faith of the Son of God , who loved me and gave himself up for me .
# My message , today , is the same as it was 15 years ago : that there is goodness in people , and strength and love in God .
# Wendell Phillips ( 1811-1884 ) , from a prominent Massachusetts family , in his teens was converted under the preaching of Lyman Beecher .
# Nor , when we recollect how sensitive were the emotions of the old Puritan stock in regard to the recent tides of immigration , should we be astonished that their thin lips were compressed into a white line of rage as Parker snarled at them thus : `` Talk about the Catholics voting as the bishop tells ! !
# It is said that fear in human beings produces an odor that provokes animals to attack .
# We are evidently trying hard to think of new ways to deal with the problem of fear these days .
# Practically everybody in Berlin has relatives and friends that live in the opposite part of the city .
# The hated dictator Batista had fled .
# There were many letters of strong protest against the portrait of the Anglican clergyman , who was indeed portrayed as a man not particularly concerned with religious matters and without really very much to do as clergyman .
# `` You're so preoccupied that you've let your faith grow dim .
# They have insisted , rather , on living fully and completely within modern culture and , so far from considering this treason to God , have looked upon it as the only way they could be faithful to him .
# therefore there is no need for him , as there is for Origen , to identify existence itself with the fall .
# But how can one figure symbolize both ? ?
# But one does not have to affirm the existence of an evil order irredeemable in that sense , or a static order in which no changes will take place in time , to be able truthfully to affirm the following fact : there has never been justitia imprinted in social institutions and social relationships except in the context of some pax-ordo preserved by clothed or naked force .

# %% [markdown]
# <h2 style='direction:rtl;'> § نرمالایز کردن  </h2>

# %%
[x.lower() for x in nltk.corpus.stopwords.words('english')]
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
def normalize_sentence(tokenized_sents, minimum_length=2, stopword_removal=True, stopwords_domain=[], lower_case=False, punctuation_removal=True):
    '''
    normalization function
    '''
    normalized_sents = tokenized_sents
    
    if stopword_removal:
        # Remove stopwords in English and also the given domain stopwords
        stopwords = [x.lower() for x in nltk.corpus.stopwords.words('english')]
        normalized_sents=[[word for word in sentence if (word.lower() not in stopwords_domain + stopwords)] for sentence in tokenized_sents ]

    if punctuation_removal:
        # Remove punctuations
        normalized_sents=[[word for word in sentence if word not in string.punctuation] for sentence in normalized_sents ]

    if lower_case:
        # Convert everything to lowercase and filter based on a min length
        normalized_sents=[[word.lower() for word in sentence if len(word)>minimum_length] for sentence in normalized_sents ]

    elif minimum_length>1:
        normalized_sents= [[word for word in sentence if len(word)>minimum_length] for sentence in normalized_sents ]        
        
    return normalized_sents

# %%
normalized_sentences_religion = normalize_sentence(all_brown_sentences_religion)
normalized_sentences_news = normalize_sentence(all_brown_sentences_news)

# %%
for x in normalized_sentences_news[0:3] + normalized_sentences_religion[0:3]:
    print(x)
    print()
# Out:
# ['Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'investigation', "Atlanta's", 'recent', 'primary', 'election', 'produced', 'evidence', 'irregularities', 'took', 'place']
#
# ['jury', 'said', 'term-end', 'presentments', 'City', 'Executive', 'Committee', 'over-all', 'charge', 'election', 'deserves', 'praise', 'thanks', 'City', 'Atlanta', 'manner', 'election', 'conducted']
#
# ['September-October', 'term', 'jury', 'charged', 'Fulton', 'Superior', 'Court', 'Judge', 'Durwood', 'Pye', 'investigate', 'reports', 'possible', 'irregularities', 'hard-fought', 'primary', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.']
#
# ['result', 'although', 'still', 'make', 'use', 'distinction', 'much', 'confusion', 'meaning', 'basic', 'terms', 'employed']
#
# ['meant', 'spirit', 'matter']
#
# ['terms', 'generally', 'taken', 'granted', 'though', 'referred', 'direct', 'axiomatic', 'elements', 'common', 'experience']

# %%
from nltk.probability import FreqDist
import numpy as np
import itertools

mp_freqdist = FreqDist(itertools.chain(*normalized_sentences_religion))               # compute the frequency distribution
top20words=mp_freqdist.most_common(20)      # show the top 20 (word, frequency) pairs
print ('%-16s' % 'word', '%-16s' % 'Frequency','%-16s' %  '% of the total')
for topword in top20words:
    percent=(topword[1]/len(normalized_sentences_religion))*100
    print ('%-16s' % topword[0], '%-16s' % topword[1],'%-16s' %  percent)
# Out:
# word             Frequency        % of the total
# God              131              7.634032634032634
# world            90               5.244755244755245
# one              87               5.06993006993007
# may              78               4.545454545454546
# new              77               4.487179487179487
# would            68               3.9627039627039626
# man              64               3.7296037296037294
# could            59               3.4382284382284385
# Christ           59               3.4382284382284385
# also             56               3.263403263403263
# life             55               3.205128205128205
# must             54               3.146853146853147
# church           51               2.972027972027972
# Christian        50               2.9137529137529135
# power            49               2.8554778554778557
# members          49               2.8554778554778557
# spirit           46               2.6806526806526807
# many             46               2.6806526806526807
# human            43               2.505827505827506
# Church           43               2.505827505827506

# %% [markdown]
# # Religion

# %%
sentence_words = list(itertools.chain(*normalized_sentences_religion))
print ('%-16s' % 'Number of words', '%-16s' % len(sentence_words))
print ('%-16s' % 'Number of unique words', '%-16s' % len(set(sentence_words)))
avg=np.sum([len(word) for word in sentence_words])/len(sentence_words)
print ('%-16s' % 'Average word length', '%-16s' % avg)
avg_sentence_length_c=np.mean([len(' '.join(sentence)) for sentence in sentence_words])
print ('%-16s' % 'Average sentence length in characters', '%-16s' % avg_sentence_length_c)
print ('%-16s' % 'Longest word', '%-16s' % sentence_words[np.argmax([len(word) for word in sentence_words])])
# Out:
# Number of words  17145
# Number of unique words 6081
# Average word length 6.614289880431612
# Average sentence length in characters 12.228579760863225
# Longest word     Preparation-Inquirers'

# %% [markdown]
# # News

# %%
sentence_words = list(itertools.chain(*normalized_sentences_news))
print ('%-16s' % 'Number of words', '%-16s' % len(sentence_words))
print ('%-16s' % 'Number of unique words', '%-16s' % len(set(sentence_words)))
avg=np.sum([len(word) for word in sentence_words])/len(sentence_words)
print ('%-16s' % 'Average word length', '%-16s' % avg)
avg_sentence_length_c=np.mean([len(' '.join(sentence)) for sentence in sentence_words])
print ('%-16s' % 'Average sentence length in characters', '%-16s' % avg_sentence_length_c)
print ('%-16s' % 'Longest word', '%-16s' % sentence_words[np.argmax([len(word) for word in sentence_words])])
# Out:
# Number of words  50351
# Number of unique words 13970
# Average word length 6.407380191058768
# Average sentence length in characters 11.814760382117536
# Longest word     Scotch-Irish-Scandinavian

# %% [markdown]
# <h2 style='direction:rtl;'> § توکنایزیشن  </h2>

# %%
# Sample

text = 'The delta variant of COVID-19 is not done with the U.S.'

# http://stackoverflow.com/questions/36353125/nltk-regular-expression-tokenizer
pattern = r'''(?x)          # set flag to allow verbose regexps
        (?:[A-Z]\.)+        # abbreviations, e.g. U.S.A.
      | \w+(?:-\w+)*        # words with optional internal hyphens
      | \$?\d+(?:\.\d+)?%?\s?  # currency and percentages, e.g. $12.40, 82%
      | \.\.\.              # ellipsis
      | [][.,;"'?():_`-]    # these are separate tokens; includes ], [
    '''

pattern = re.compile(pattern)

tokenized_abstracts=nltk.regexp_tokenize(text, pattern)
tokenized_abstracts
# Out:
# ['The',
#  'delta',
#  'variant',
#  'of',
#  'COVID-19',
#  'is',
#  'not',
#  'done',
#  'with',
#  'the',
#  'U.S.']

# %% [markdown]
# <h2 style='direction:rtl;'> § جمله‌بندی  </h2>

# %%
# Example in NLTK

from nltk.tokenize import sent_tokenize

text="""Hi Tom, how are you? I’m fine, thanks. How are you? Great! thank you."""

sents=sent_tokenize(text)
for x in sents:
    print(x)
# Out:
# Hi Tom, how are you?
# I’m fine, thanks.
# How are you?
# Great!
# thank you.

# %%
# Explore Spacy
#!pip install spacy
#!python -m spacy download en_core_web_sm

import spacy

nlp = spacy.load('en_core_web_sm') # or whatever model you have installed

# %%
doc = nlp(text)

# %%
sents = [sent for sent in doc.sents]
for x in sents:
    print([(tok.pos_,tok.lemma_) for tok in x])
# Out:
# [('INTJ', 'hi'), ('PROPN', 'Tom'), ('PUNCT', ','), ('SCONJ', 'how'), ('AUX', 'be'), ('PRON', 'you'), ('PUNCT', '?')]
# [('PRON', 'I'), ('VERB', '’m'), ('ADJ', 'fine'), ('PUNCT', ','), ('NOUN', 'thank'), ('PUNCT', '.')]
# [('SCONJ', 'how'), ('AUX', 'be'), ('PRON', 'you'), ('PUNCT', '?')]
# [('ADJ', 'great'), ('PUNCT', '!')]
# [('VERB', 'thank'), ('PRON', 'you'), ('PUNCT', '.')]

# %%
doc = nlp("Of the various modern languages used in Iran, Persian, various dialects of which are spoken throughout the Iranian Plateau,[468][469] has the most influential literature. Persian has been dubbed as a worthy language to serve as a conduit for poetry, and is considered one of the four main bodies of world literature")
for t in doc.ents:
    print(t.text, t.label_)
# Out:
# Iran GPE
# Persian NORP
# Iranian NORP
# Persian NORP
# four CARDINAL

# %%
import spacy
from spacy import displacy

displacy.serve(doc, style="dep")
# Out:
# /Users/ehsan/opt/anaconda3/envs/nlpclass/lib/python3.9/site-packages/spacy/displacy/__init__.py:98: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4bf41b772b034640a5d1f79bf6fd7a2a-0" class="displacy" width="8975" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">various</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">modern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">languages</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">used</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Iran,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Persian,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">various</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">dialects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">spoken</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">throughout</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Iranian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Plateau,[468][469]</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">influential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">literature.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Persian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">dubbed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
for tok in list(doc.sents)[0]:
    print(tok.text, tok.pos_, tok.lemma_, tok.dep_, tok.head)
# Out:
# Of ADP of prep spoken
# the DET the det languages
# various ADJ various amod languages
# modern ADJ modern amod languages
# languages NOUN language pobj Of
# used VERB use acl languages
# in ADP in prep used
# Iran PROPN Iran pobj in
# , PUNCT , punct Iran
# Persian PROPN Persian conj Iran
# , PUNCT , punct Persian
# various ADJ various amod dialects
# dialects NOUN dialect nsubjpass spoken
# of ADP of prep dialects
# which PRON which pobj of
# are AUX be auxpass spoken
# spoken VERB speak ROOT spoken
# throughout ADP throughout prep spoken
# the DET the det Plateau,[468][469
# Iranian ADJ iranian amod Plateau,[468][469
# Plateau,[468][469 NOUN Plateau,[468][469 pobj throughout
# ] PUNCT ] punct spoken
# has AUX have dep spoken
# the DET the det literature
# most ADV most advmod influential
# influential ADJ influential amod literature
# literature NOUN literature dobj has
# . PUNCT . punct spoken

# %% [markdown]
# <h2 style='direction:rtl;'> § تحلیل بسامد  </h2>

# %%
from nltk import FreqDist
import itertools
import pandas as pd

all_tokens_religion = list(itertools.chain(*normalized_sentences_religion))
all_tokens_news = list(itertools.chain(*normalized_sentences_news))


dataframe = {}

for opt in ['religion', 'news']:
     dataframe[opt] = FreqDist(eval(F"all_tokens_{opt}")).most_common(50)

freq_analysis = pd.DataFrame(dataframe)

# %%
freq_analysis
# Out:
#             religion                  news
# 0         (God, 131)           (said, 402)
# 1        (world, 90)           (Mrs., 253)
# 2          (one, 87)          (would, 244)
# 3          (may, 78)            (one, 184)
# 4          (new, 77)            (Mr., 170)
# 5        (would, 68)           (last, 161)
# 6          (man, 64)            (two, 157)
# 7        (could, 59)            (new, 148)
# 8       (Christ, 59)          (first, 143)
# 9         (also, 56)           (year, 138)
# 10        (life, 55)           (home, 127)
# 11        (must, 54)           (also, 120)
# 12      (church, 51)           (made, 107)
# 13   (Christian, 50)          (years, 102)
# 14       (power, 49)            (time, 97)
# 15     (members, 49)           (three, 97)
# 16      (spirit, 46)             (New, 93)
# 17        (many, 46)           (state, 90)
# 18       (human, 43)       (President, 89)
# 19      (Church, 43)            (week, 86)
# 20       (death, 41)           (could, 86)
# 21       (faith, 40)            (four, 73)
# 22         (say, 39)             (man, 72)
# 23        (even, 39)           (House, 71)
# 24         (men, 39)            (back, 69)
# 25        (good, 37)         (members, 69)
# 26       (years, 37)        (American, 67)
# 27     (England, 37)             (may, 66)
# 28       (still, 35)         (program, 66)
# 29         (see, 35)            (work, 66)
# 30        (time, 34)             (get, 66)
# 31      (people, 34)         (Kennedy, 66)
# 32    (Catholic, 34)            (John, 65)
# 33       (Jesus, 33)          (school, 65)
# 34      (number, 33)           (night, 64)
# 35  (membership, 33)           (State, 63)
# 36        (born, 33)         (meeting, 62)
# 37         (way, 31)           (since, 61)
# 38        (know, 30)             (per, 61)
# 39        (John, 30)             (day, 61)
# 40         (sin, 30)            (many, 60)
# 41      (action, 30)            (U.S., 58)
# 42    (churches, 29)          (United, 58)
# 43        (much, 28)       (yesterday, 56)
# 44        (made, 28)          (Monday, 54)
# 45         (St., 28)             (tax, 53)
# 46      (Parker, 28)            (told, 53)
# 47  (experience, 27)       (president, 53)
# 48         (two, 27)            (even, 53)
# 49        (said, 27)  (administration, 52)

# %% [markdown]
# <h2 style='direction:rtl;'> § استفاده از lemmatization, stemming  </h2>

# %%
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
stemmer  = PorterStemmer()


def get_lemma_set(tok, opt=1):
    if opt ==1:
        return stemmer.stem(tok)
    if opt ==2:
        return lemmatizer.lemmatize(tok)
    if opt ==3:
        # write your own
        pass

# %%
word='narration'
print(F"Word: {word}, Stem: {stemmer.stem(word)}, Lemma:{lemmatizer.lemmatize(word)}, Lemma spacy: {[tok.lemma_ for tok in nlp(word)][0]}")
# Out:
# Word: narration, Stem: narrat, Lemma:narration, Lemma spacy: narration

# %%
opt = 1

religion_tokens_nonstop_lemstem =   [get_lemma_set(t, opt) for t in tqdm.tqdm(all_tokens_religion)]
news_tokens_nonstop_lemstem = [get_lemma_set(t, opt) for t in tqdm.tqdm(all_tokens_news)]

dataframe_nonstop_lemstem = {}

for opt in ['religion', 'news']:
     dataframe_nonstop_lemstem[opt] = FreqDist(eval(F"{opt}_tokens_nonstop_lemstem")).most_common(50)

freq_analysis_nonstop_lemstem = pd.DataFrame(dataframe_nonstop_lemstem)   
freq_analysis_nonstop_lemstem
# Out:
# 100%|███████████████████████████████████████████████████████████| 17145/17145 [00:00<00:00, 52666.37it/s]
# 100%|███████████████████████████████████████████████████████████| 50351/50351 [00:00<00:00, 52662.74it/s]
#             religion            news
# 0         (god, 138)     (said, 406)
# 1      (church, 127)     (mrs., 253)
# 2         (one, 110)    (would, 246)
# 3          (new, 99)     (year, 244)
# 4        (world, 95)      (new, 242)
# 5          (may, 79)      (one, 221)
# 6    (christian, 79)    (state, 219)
# 7       (spirit, 71)     (last, 179)
# 8        (would, 69)      (two, 174)
# 9          (man, 68)      (mr., 170)
# 10       (power, 68)    (first, 158)
# 11      (member, 60)   (presid, 147)
# 12       (could, 59)     (home, 141)
# 13      (christ, 59)     (time, 133)
# 14        (mean, 57)     (also, 129)
# 15        (also, 57)   (school, 127)
# 16        (life, 55)     (hous, 123)
# 17         (say, 55)     (week, 120)
# 18      (number, 55)      (day, 116)
# 19        (must, 54)   (nation, 116)
# 20        (mani, 52)   (member, 109)
# 21      (cathol, 52)     (made, 107)
# 22        (even, 51)     (work, 104)
# 23       (human, 50)      (may, 103)
# 24       (faith, 47)    (three, 101)
# 25        (live, 46)      (citi, 99)
# 26       (natur, 45)      (meet, 97)
# 27        (year, 45)       (get, 95)
# 28         (way, 44)      (bill, 90)
# 29     (univers, 43)      (plan, 88)
# 30         (see, 42)     (could, 87)
# 31         (men, 42)      (play, 87)
# 32       (death, 42)    (govern, 83)
# 33        (word, 40)      (four, 82)
# 34        (time, 40)  (committe, 81)
# 35       (peopl, 40)      (make, 80)
# 36       (thing, 40)    (servic, 79)
# 37        (good, 40)   (program, 79)
# 38        (atom, 40)  (american, 79)
# 39       (still, 39)       (run, 78)
# 40         (sin, 39)      (unit, 78)
# 41        (fear, 38)    (report, 76)
# 42        (know, 38)      (back, 76)
# 43        (work, 38)   (univers, 76)
# 44      (commun, 37)    (counti, 75)
# 45     (england, 37)      (take, 75)
# 46      (person, 37)       (man, 75)
# 47  (membership, 37)      (game, 75)
# 48       (state, 36)       (tax, 74)
# 49        (make, 35)      (even, 74)

# %% [markdown]
# <h2 style='direction:rtl;'> § استفاده از POS-tags  </h2>

# %%
from nltk import word_tokenize, pos_tag

# %%
def create_data_sets(sentences):
    size = int(len(sentences) * 0.9)
    train_sents = sentences[:size]
    test_sents = sentences[size:]
    return train_sents, test_sents

def build_backoff_tagger (train_sents):
    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(train_sents, backoff=t0)
    t2 = nltk.BigramTagger(train_sents, backoff=t1)
    return t2


def train_tagger(already_tagged_sents):
    train_sents, test_sents = create_data_sets(already_tagged_sents)
    ngram_tagger = build_backoff_tagger(train_sents)
    print ("%0.3f pos accuracy on test set" % ngram_tagger.evaluate(test_sents))
    return ngram_tagger

# %%
brown_tagged_sents = brown.tagged_sents(categories=['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies',
    'humor', 'learned', 'lore', 'mystery', 'religion', 'reviews', 'romance','science_fiction'])

# %%
brown_tagged_sents[0]
# Out:
# [('Assembly', 'NN-HL'),
#  ('session', 'NN-HL'),
#  ('brought', 'VBD-HL'),
#  ('much', 'AP-HL'),
#  ('good', 'NN-HL')]

# %%
brown_tagger = train_tagger(brown_tagged_sents)
# Out:
# 0.911 pos accuracy on test set

# %%
brown_tagger.tag(globals()[F'normalized_sentences_{opt}'][0])
# Out:
# [('Fulton', 'NP'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('investigation', 'NN'),
#  ("Atlanta's", 'NN'),
#  ('recent', 'JJ'),
#  ('primary', 'JJ'),
#  ('election', 'NN'),
#  ('produced', 'VBN'),
#  ('evidence', 'NN'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN')]

# %%
pos_tag(globals()[F'normalized_sentences_{opt}'][0])
# Out:
# [('Fulton', 'NNP'),
#  ('County', 'NNP'),
#  ('Grand', 'NNP'),
#  ('Jury', 'NNP'),
#  ('said', 'VBD'),
#  ('Friday', 'NNP'),
#  ('investigation', 'NN'),
#  ("Atlanta's", 'NNP'),
#  ('recent', 'JJ'),
#  ('primary', 'JJ'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('evidence', 'NN'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN')]

# %%
import copy
dataframe_nonstop_lemstem_advjj = {}

for opt in tqdm.tqdm(['religion', 'news']):
    selected = []
    for sentence in globals()[F'normalized_sentences_{opt}']:
        tagged_sentence = brown_tagger.tag(sentence)
        for w, pos in tagged_sentence:
            if pos=='JJ':
                selected.append(w) 
    dataframe_nonstop_lemstem_advjj[opt]= list(FreqDist(selected).most_common(40))

dataframe_nonstop_lemstem_advjj = pd.DataFrame(dataframe_nonstop_lemstem_advjj)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.52it/s]

# %%
dataframe_nonstop_lemstem_advjj
# Out:
#               religion                 news
# 0            (new, 77)           (new, 148)
# 1      (Christian, 48)       (American, 66)
# 2          (human, 43)           (high, 52)
# 3       (Catholic, 33)         (public, 50)
# 4           (good, 29)           (good, 49)
# 5      (religious, 27)        (special, 41)
# 6          (great, 26)          (local, 39)
# 7         (social, 26)            (big, 38)
# 8      (spiritual, 25)        (federal, 35)
# 9          (moral, 21)          (young, 35)
# 10          (real, 20)           (long, 34)
# 11        (modern, 18)         (annual, 33)
# 12       (Chinese, 18)       (national, 32)
# 13     (important, 17)       (military, 30)
# 14      (American, 17)          (great, 30)
# 15       (certain, 17)        (foreign, 29)
# 16         (whole, 15)       (possible, 28)
# 17      (possible, 15)      (political, 27)
# 18     (political, 15)          (small, 27)
# 19          (evil, 14)           (open, 26)
# 20    (Protestant, 14)          (major, 25)
# 21      (personal, 14)          (large, 25)
# 22       (natural, 14)           (able, 24)
# 23         (magic, 14)        (British, 24)
# 24   (traditional, 13)            (old, 23)
# 25       (English, 13)  (international, 23)
# 26         (small, 13)          (final, 21)
# 27          (true, 12)       (Catholic, 21)
# 28         (Roman, 12)     (anti-trust, 21)
# 29        (entire, 12)         (recent, 20)
# 30   (theological, 11)        (private, 19)
# 31        (public, 11)        (medical, 18)
# 32  (anti-slavery, 11)        (certain, 18)
# 33         (large, 10)       (complete, 18)
# 34    (individual, 10)      (necessary, 18)
# 35        (recent, 10)           (full, 18)
# 36  (professional, 10)        (similar, 17)
# 37       (nuclear, 10)           (real, 17)
# 38         (common, 9)         (social, 17)
# 39        (popular, 9)           (fine, 16)

# %% [markdown]
# <h2 style='direction:rtl;'> § دیدن سیاق  </h2>

# %%
hafez_text = nltk.Text(religion_tokens_nonstop_lemstem)
hafez_text.concordance('Spirit')
# Out:
# Displaying 25 of 25 matches:
#  spirit matter term gener taken grant though
# precis one must modern world neither spirit matter refer gener agreed-upon eleme
# ght almost univers disbelief realiti spirit centuri ago world spirit popul real
# ief realiti spirit centuri ago world spirit popul real world materi entiti popul
# man rock tree star world word matter spirit refer directli known realiti common
# f categori realiti larg extent empti spirit world entiti previous popul carri pr
# rvic claim due credit objectif world spirit popular superstit certainli gone far
# tit certainli gone far beyond experi spirit could justifi support scienc fulli c
# et entiti popular imagin peopl world spirit entiti soon lost whatev statu enjoy
# te howev unmix bless scientif debunk spirit world way success thorough hous swep
# best wholli inadequ mean deal experi spirit although particular form conceptu po
# u popular imagin made respons experi spirit undoubtedli defect raw experi led ex
# c leav play spell kind spell exposur spirit live activ manifest alway evok one a
# hin terribl power better answer give spirit attempt say spirit employ commonli u
# etter answer give spirit attempt say spirit employ commonli use word design simp
# ter mind hale' still convinc societi spirit beyond ken page hand littl later say
# t come watch play like spell realiti spirit emerg play spite author' convict con
#  play spite author' convict contrari spirit commun noth whole rang human experi
# human experi wide known univers felt spirit apart spirit could commun spirit dra
# wide known univers felt spirit apart spirit could commun spirit draw men commun
# elt spirit apart spirit could commun spirit draw men commun give commun uniti co
# mmun uniti cohes perman think exampl spirit marin corp sure realiti acknowledg c
#  object realiti experienc known mani spirit know spirit nazism commun school spi
# iti experienc known mani spirit know spirit nazism commun school spirit spirit s
# rit know spirit nazism commun school spirit spirit street corner gang footbal te

# %% [markdown]
# <h2 style='direction:rtl;'> § عبارت یابی  </h2>

# %%
import nltk
nltk.download('inaugural')
# Out:
# [nltk_data] Downloading package inaugural to /Users/ehsan/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# True

# %%
from nltk.corpus import inaugural

print(inaugural.fileids())
print()
# Out:
# ['1789-Washington.txt', '1793-Washington.txt', '1797-Adams.txt', '1801-Jefferson.txt', '1805-Jefferson.txt', '1809-Madison.txt', '1813-Madison.txt', '1817-Monroe.txt', '1821-Monroe.txt', '1825-Adams.txt', '1829-Jackson.txt', '1833-Jackson.txt', '1837-VanBuren.txt', '1841-Harrison.txt', '1845-Polk.txt', '1849-Taylor.txt', '1853-Pierce.txt', '1857-Buchanan.txt', '1861-Lincoln.txt', '1865-Lincoln.txt', '1869-Grant.txt', '1873-Grant.txt', '1877-Hayes.txt', '1881-Garfield.txt', '1885-Cleveland.txt', '1889-Harrison.txt', '1893-Cleveland.txt', '1897-McKinley.txt', '1901-McKinley.txt', '1905-Roosevelt.txt', '1909-Taft.txt', '1913-Wilson.txt', '1917-Wilson.txt', '1921-Harding.txt', '1925-Coolidge.txt', '1929-Hoover.txt', '1933-Roosevelt.txt', '1937-Roosevelt.txt', '1941-Roosevelt.txt', '1945-Roosevelt.txt', '1949-Truman.txt', '1953-Eisenhower.txt', '1957-Eisenhower.txt', '1961-Kennedy.txt', '1965-Johnson.txt', '1969-Nixon.txt', '1973-Nixon.txt', '1977-Carter.txt', '1981-Reagan.txt', '1985-Reagan.txt', '1989-Bush.txt', '1993-Clinton.txt', '1997-Clinton.txt', '2001-Bush.txt', '2005-Bush.txt', '2009-Obama.txt', '2013-Obama.txt', '2017-Trump.txt', '2021-Biden.txt']

# %%
Lincoln = list(inaugural.words(inaugural.fileids()[18]))
Obama = list(inaugural.words(inaugural.fileids()[56]))
Trump = list(inaugural.words(inaugural.fileids()[57]))
Biden = list(inaugural.words(inaugural.fileids()[58]))


Lincoln =' '.join(Lincoln)
Lincoln_sentences =  sent_tokenize(Lincoln)
Lincoln_sentences =  [x.split() for x in Lincoln_sentences]
Lincoln_sentences_tagged = [brown_tagger.tag(sent) for sent in Lincoln_sentences]

Obama =' '.join(Obama)
Obama_sentences =  sent_tokenize(Obama)
Obama_sentences =  [x.split() for x in Obama_sentences]
Obama_sentences_tagged = [brown_tagger.tag(sent) for sent in Obama_sentences]

Trump =' '.join(Trump)
Trump_sentences =  sent_tokenize(Trump)
Trump_sentences =  [x.split() for x in Trump_sentences]
Trump_sentences_tagged = [brown_tagger.tag(sent) for sent in Trump_sentences]

Biden =' '.join(Biden)
Biden_sentences =  sent_tokenize(Biden)
Biden_sentences =  [x.split() for x in Biden_sentences]
Biden_sentences_tagged = [brown_tagger.tag(sent) for sent in Biden_sentences]

# %%
sentence_words = list(itertools.chain(*Lincoln_sentences))
print ('%-16s' % 'Number of words', '%-16s' % len(sentence_words))
print ('%-16s' % 'Number of unique words', '%-16s' % len(set(sentence_words)))
avg=np.sum([len(word) for word in sentence_words])/len(sentence_words)
print ('%-16s' % 'Average word length', '%-16s' % avg)
avg_sentence_length_c=np.mean([len(' '.join(sentence)) for sentence in sentence_words])
print ('%-16s' % 'Average sentence length in characters', '%-16s' % avg_sentence_length_c)
print ('%-16s' % 'Longest word', '%-16s' % sentence_words[np.argmax([len(word) for word in sentence_words])])
# Out:
# Number of words  4005
# Number of unique words 1078
# Average word length 4.329588014981273
# Average sentence length in characters 7.659176029962547
# Longest word     unconstitutional

# %%
sentence_words = list(itertools.chain(*Obama_sentences))
print ('%-16s' % 'Number of words', '%-16s' % len(sentence_words))
print ('%-16s' % 'Number of unique words', '%-16s' % len(set(sentence_words)))
avg=np.sum([len(word) for word in sentence_words])/len(sentence_words)
print ('%-16s' % 'Average word length', '%-16s' % avg)
avg_sentence_length_c=np.mean([len(' '.join(sentence)) for sentence in sentence_words])
print ('%-16s' % 'Average sentence length in characters', '%-16s' % avg_sentence_length_c)
print ('%-16s' % 'Longest word', '%-16s' % sentence_words[np.argmax([len(word) for word in sentence_words])])
# Out:
# Number of words  2369
# Number of unique words 820
# Average word length 4.149430139299282
# Average sentence length in characters 7.298860278598565
# Longest word     responsibility

# %%
sentence_words = list(itertools.chain(*Trump_sentences))
print ('%-16s' % 'Number of words', '%-16s' % len(sentence_words))
print ('%-16s' % 'Number of unique words', '%-16s' % len(set(sentence_words)))
avg=np.sum([len(word) for word in sentence_words])/len(sentence_words)
print ('%-16s' % 'Average word length', '%-16s' % avg)
avg_sentence_length_c=np.mean([len(' '.join(sentence)) for sentence in sentence_words])
print ('%-16s' % 'Average sentence length in characters', '%-16s' % avg_sentence_length_c)
print ('%-16s' % 'Longest word', '%-16s' % sentence_words[np.argmax([len(word) for word in sentence_words])])
# Out:
# Number of words  1693
# Number of unique words 582
# Average word length 4.112226816302422
# Average sentence length in characters 7.224453632604844
# Longest word     administration

# %%
sentence_words = list(itertools.chain(*Biden_sentences))
print ('%-16s' % 'Number of words', '%-16s' % len(sentence_words))
print ('%-16s' % 'Number of unique words', '%-16s' % len(set(sentence_words)))
avg=np.sum([len(word) for word in sentence_words])/len(sentence_words)
print ('%-16s' % 'Average word length', '%-16s' % avg)
avg_sentence_length_c=np.mean([len(' '.join(sentence)) for sentence in sentence_words])
print ('%-16s' % 'Average sentence length in characters', '%-16s' % avg_sentence_length_c)
print ('%-16s' % 'Longest word', '%-16s' % sentence_words[np.argmax([len(word) for word in sentence_words])])
# Out:
# Number of words  3104
# Number of unique words 845
# Average word length 3.6688144329896906
# Average sentence length in characters 6.337628865979381
# Longest word     responsibilities

# %%
def chunkTechnicalTerm(sentence):
    grammar = r"""
      TECHTERM: {<JJ|NN>+<NN|CD>|<NN>}
    """
    cp = nltk.RegexpParser(grammar)
    return (cp.parse(sentence))

# %%
import copy

technical_terms = {}
opt_technical_terms = {}



for opt in tqdm.tqdm(['Lincoln', 'Obama','Trump','Biden']):
    technical_terms[opt] = []
    tagged = globals()[F'{opt}_sentences_tagged']
    for sentence in tagged:
        tree=chunkTechnicalTerm(sentence)
        for subtree in tree.subtrees():
            if subtree.label() == 'TECHTERM':
                technical_terms[opt].append(subtree.leaves())
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 71.96it/s]

# %%
for opt in tqdm.tqdm(['Lincoln', 'Obama','Trump','Biden']):
    opt_technical_terms[opt]=FreqDist([' '.join([x for x,y in sent]) for sent in technical_terms[opt] if len(sent)>1]).most_common(40)
# Out:
# 100%|████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 1734.62it/s]

# %%
opt_technical_terms = pd.DataFrame(opt_technical_terms) 
opt_technical_terms
# Out:
#                            Lincoln                         Obama  \
# 0                (such service, 2)          (exceptionalâ , 1)
# 1                 (organic law, 2)             (Americanâ , 1)
# 2        (constitutional right, 2)           (modern economy, 1)
# 3         (foreign slave trade, 2)              (free market, 1)
# 4               (whole subject, 2)                (fair play, 1)
# 5                   (office .", 1)             (great nation, 1)
# 6             (special anxiety, 1)        (central authority, 1)
# 7           (personal security, 1)                (hard work, 1)
# 8            (reasonable cause, 1)  (personal responsibility, 1)
# 9           (such apprehension, 1)        (collective action, 1)
# 10             (ample evidence, 1)                  (s world, 1)
# 11               (lawful right, 1)            (research labs, 1)
# 12             (full knowledge, 1)        (economic recovery, 1)
# 13        (emphatic resolution, 1)         (endless capacity, 1)
# 14               (own judgment, 1)                   (itâ , 1)
# 15           (political fabric, 1)             (s prosperity, 1)
# 16           (lawless invasion, 1)             (middle class, 1)
# 17           (public attention, 1)             (honest labor, 1)
# 18        (conclusive evidence, 1)              (little girl, 1)
# 19                   (clause ", 1)         (bleakest poverty, 1)
# 20                (good temper, 1)             (real meaning, 1)
# 21      (equal unanimity frame, 1)            (basic measure, 1)
# 22             (unanimous oath, 1)              (health care, 1)
# 23               (material one, 1)          (country freedom, 1)
# 24         (little consequence, 1)                 (job loss, 1)
# 25  (unsubstantial controversy, 1)           (sudden illness, 1)
# 26       (humane jurisprudence, 1)           (terrible storm, 1)
# 27                   (free man, 1)    (overwhelming judgment, 1)
# 28              (official oath, 1)       (sustainable energy, 1)
# 29             (period fifteen, 1)        (economic vitality, 1)
# 30           (executive branch, 1)    (national treasureâ , 1)
# 31              (great success, 1)            (perpetual war, 1)
# 32  (brief constitutional term, 1)              (friendsâ , 1)
# 33        (peculiar difficulty, 1)           (peacefullyâ , 1)
# 34              (universal law, 1)           (peaceful world, 1)
# 35            (fundamental law, 1)          (powerful nation, 1)
# 36            (own termination, 1)            (prejudiceâ , 1)
# 37           (peaceably unmade, 1)             (mere charity, 1)
# 38           (lawfully rescind, 1)         (constant advance, 1)
# 39        (legal contemplation, 1)             (common creed, 1)
#
#                              Trump                     Biden
# 0          (transferring power, 2)       (American story, 3)
# 1       (great national effort, 1)           (whole soul, 3)
# 2           (peaceful transfer, 1)                (s day, 2)
# 3              (Michelle Obama, 1)          (sacred oath, 2)
# 4                (gracious aid, 1)       (racial justice, 2)
# 5                  (s ceremony, 1)          (health care, 2)
# 6             (special meaning, 1)               (usâ , 2)
# 7                 (small group, 1)        (silent prayer, 2)
# 8           (historic movement, 1)           (peopleâ , 1)
# 9          (crucial conviction, 1)    (peaceful transfer, 1)
# 10          (different reality, 1)     (American wayâ , 1)
# 11           (education system, 1)       (optimisticâ , 1)
# 12       (unrealized potential, 1)        (perfect Union, 1)
# 13           (glorious destiny, 1)             (ll press, 1)
# 14           (foreign industry, 1)            (s history, 1)
# 15          (American industry, 1)        (century virus, 1)
# 16              (sad depletion, 1)  (political extremism, 1)
# 17           (s infrastructure, 1)   (domestic terrorism, 1)
# 18                 (rich while, 1)       (challengesâ , 1)
# 19               (middle class, 1)          (Americaâ , 1)
# 20                 (new decree, 1)         (deadly virus, 1)
# 21            (foreign capital, 1)          (reward work, 1)
# 22                 (new vision, 1)         (middle class, 1)
# 23           (great prosperity, 1)      (foolish fantasy, 1)
# 24             (American labor, 1)    (constant struggle, 1)
# 25                  (good will, 1)       (American ideal, 1)
# 26                (exampleâ , 1)         (ugly reality, 1)
# 27                  (shineâ , 1)      (historic moment, 1)
# 28  (radical Islamic terrorism, 1)              (s start, 1)
# 29           (total allegiance, 1)       (Politics doesn, 1)
# 30                   (unity .", 1)   (disagreement doesn, 1)
# 31            (law enforcement, 1)            (total war, 1)
# 32                 (empty talk, 1)     (American history, 1)
# 33             (new millennium, 1)      (national office, 1)
# 34         (new national pride, 1)         (full measure, 1)
# 35                     (s time, 1)        (eternal peace, 1)
# 36                 (old wisdom, 1)          (riotous mob, 1)
# 37                  (red blood, 1)        (sacred ground, 1)
# 38        (great American flag, 1)             (everâ , 1)
# 39               (urban sprawl, 1)          (s democracy, 1)

# %% [markdown]
# <h2 style='direction:rtl;'> § WordNet  </h2>

# %%
from nltk.collocations import *
from string import *

def freq_normed_unigrams(sents):
    wnl = WordNetLemmatizer() # to get word stems
    
    tagged_POS_sents = [nltk.pos_tag(sent) for sent in sents] # tags sents
    
    normed_tagged_words = [wnl.lemmatize(word[0].lower()) for sent in tagged_POS_sents
                           for word in sent 
                           if word[0].lower() not in nltk.corpus.stopwords.words('english')
                           and word[0] not in punctuation # remove punctuation
                           and not re.search(r'''^[\.,;"'?!():\-_`]+$''', word[0])
                           and word[1].startswith('N')]  # include only nouns

    top_normed_unigrams = [word for (word, count) in nltk.FreqDist(normed_tagged_words).most_common(40)]
    return top_normed_unigrams

# %%
Trump_top_words = freq_normed_unigrams(Trump_sentences)
Obama_top_words = freq_normed_unigrams(Obama_sentences)
Lincoln_top_words = freq_normed_unigrams(Lincoln_sentences)
Biden_top_words = freq_normed_unigrams(Biden_sentences)

# %%
from nltk.corpus import wordnet as wn
from collections import defaultdict

def categories_from_hypernyms(termlist):
    hypterms = []
    hypterms_dict = defaultdict()
    for term in termlist:                  # for each term
        s = wn.synsets(term.lower(), 'n')  # get its nominal synsets
        for syn in s:                      # for each lemma synset
            for hyp in syn.hypernyms():    # It has a list of hypernyms
                hypterms.append(hyp.name())      # Extract the hypernym name and add to list
                if hyp.name() not in hypterms_dict:
                    hypterms_dict[hyp.name()] = list()
                hypterms_dict[hyp.name()].append(term)  # Extract examples and add them to dict
                
    hypfd = nltk.FreqDist(hypterms)             # After going through all the nouns, print out the hypernyms 
    for (name, count) in hypfd.most_common(25):  # that have accumulated the most counts (have seen the most descendents)
        print( name, '({0})'.format(count))
        print ('\t', ', '.join(set(hypterms_dict[name])))  # show the children found for each hypernym
        print ()

# %%
categories_from_hypernyms(Biden_top_words)
# Out:
# time_period.n.01 (8)
# 	 day, century, year, time
#
# group.n.01 (4)
# 	 people, world
#
# feeling.n.01 (4)
# 	 hope, heart, thing, soul
#
# people.n.01 (3)
# 	 nation, world, country
#
# person.n.01 (3)
# 	 hope, leader, child
#
# political_unit.n.01 (2)
# 	 nation, country
#
# inhabitant.n.01 (2)
# 	 american
#
# time_unit.n.01 (2)
# 	 day
#
# time.n.03 (2)
# 	 day, moment
#
# present.n.01 (2)
# 	 today, moment
#
# record.n.01 (2)
# 	 story, history
#
# cognition.n.01 (2)
# 	 power, history
#
# concern.n.01 (2)
# 	 thing, world
#
# state.n.02 (2)
# 	 power, unity
#
# head_of_state.n.01 (2)
# 	 president
#
# attribute.n.02 (2)
# 	 thing, time
#
# quality.n.01 (2)
# 	 truth, power
#
# causal_agent.n.01 (2)
# 	 power, soul
#
# situation.n.01 (2)
# 	 challenge, thing
#
# artifact.n.01 (2)
# 	 thing, way
#
# statement.n.01 (2)
# 	 truth, thing
#
# physical_entity.n.01 (2)
# 	 cause, thing
#
# property.n.02 (2)
# 	 strength, way
#
# intensity.n.02 (2)
# 	 violence, strength
#
# power.n.01 (2)
# 	 strength

# %%
categories_from_hypernyms(Trump_top_words)
# Out:
# time_period.n.01 (8)
# 	 life, day, year
#
# people.n.01 (4)
# 	 nation, land, world, country
#
# group.n.01 (4)
# 	 people, world
#
# political_unit.n.01 (3)
# 	 nation, land, country
#
# administrative_district.n.01 (3)
# 	 land, city, country
#
# assets.n.01 (3)
# 	 share, capital
#
# person.n.01 (3)
# 	 party, life, child
#
# being.n.01 (3)
# 	 life
#
# region.n.03 (2)
# 	 land, country
#
# inhabitant.n.01 (2)
# 	 american
#
# experience.n.02 (2)
# 	 life, world
#
# head_of_state.n.01 (2)
# 	 president
#
# work.n.01 (2)
# 	 job
#
# time_unit.n.01 (2)
# 	 day
#
# boundary.n.01 (2)
# 	 border
#
# edge.n.06 (2)
# 	 border
#
# leader.n.01 (2)
# 	 politician
#
# ending.n.04 (2)
# 	 triumph, victory
#
# success.n.01 (2)
# 	 triumph, victory
#
# real_property.n.01 (2)
# 	 land
#
# object.n.01 (2)
# 	 land
#
# geographical_area.n.01 (1)
# 	 country
#
# confederation.n.02 (1)
# 	 nation
#
# family.n.04 (1)
# 	 people
#
# english.n.01 (1)
# 	 american

# %%
categories_from_hypernyms(Obama_top_words)
# Out:
# time_period.n.01 (9)
# 	 generation, year, life, time
#
# group.n.01 (5)
# 	 people, men, world
#
# people.n.01 (4)
# 	 nation, world, country, generation
#
# being.n.01 (3)
# 	 life
#
# person.n.01 (3)
# 	 life, men, child
#
# male.n.02 (3)
# 	 men
#
# direction.n.06 (3)
# 	 rule
#
# activity.n.01 (3)
# 	 effort, job, work
#
# political_unit.n.01 (2)
# 	 nation, country
#
# inhabitant.n.01 (2)
# 	 american
#
# experience.n.02 (2)
# 	 life, world
#
# freedom.n.01 (2)
# 	 liberty
#
# doctrine.n.01 (2)
# 	 creed
#
# promise.n.01 (2)
# 	 word, oath
#
# generalization.n.02 (2)
# 	 principle, rule
#
# law.n.04 (2)
# 	 principle, rule
#
# homo.n.02 (2)
# 	 men, world
#
# concept.n.01 (2)
# 	 rule
#
# duration.n.01 (2)
# 	 value, rule
#
# product.n.02 (2)
# 	 job, work
#
# work.n.01 (2)
# 	 job
#
# head_of_state.n.01 (2)
# 	 president
#
# family.n.04 (1)
# 	 people
#
# case.n.01 (1)
# 	 time
#
# moment.n.01 (1)
# 	 time

# %%
categories_from_hypernyms(Lincoln_top_words)
# Out:
# person.n.01 (6)
# 	 slave, case, authority, party
#
# time_period.n.01 (6)
# 	 term, time, year
#
# concept.n.01 (4)
# 	 section, part, law
#
# work.n.01 (4)
# 	 labor, duty, service
#
# group.n.01 (3)
# 	 people
#
# organization.n.01 (3)
# 	 union, institution, party
#
# state.n.02 (3)
# 	 union, office, power
#
# social_control.n.01 (3)
# 	 duty, administration, government
#
# administrative_district.n.01 (2)
# 	 state
#
# attribute.n.02 (2)
# 	 state, time
#
# political_unit.n.01 (2)
# 	 union, state
#
# executive_department.n.01 (2)
# 	 labor, state
#
# beginning.n.05 (2)
# 	 institution, constitution
#
# collection.n.01 (2)
# 	 hand, law
#
# force.n.04 (2)
# 	 service, law
#
# sexual_activity.n.01 (2)
# 	 union, congress
#
# happening.n.01 (2)
# 	 union, case
#
# container.n.01 (2)
# 	 case
#
# activity.n.01 (2)
# 	 service, provision
#
# number.n.01 (2)
# 	 majority, minority
#
# age.n.03 (2)
# 	 majority, minority
#
# administrative_unit.n.01 (2)
# 	 office, authority
#
# goal.n.01 (2)
# 	 purpose, object
#
# constituent.n.04 (2)
# 	 term, object
#
# resoluteness.n.01 (2)
# 	 purpose, decision
